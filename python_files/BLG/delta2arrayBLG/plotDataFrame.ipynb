# %%
import numpy as np 
import pandas as pd
import matplotlib
matplotlib.use('Qt5Agg')
from matplotlib import pyplot as plt
import sys, os
from scipy.signal import find_peaks
path_to_csv = './csvresults/'
# Out:
# /var/folders/45/s5_xwz0118sg3syff0jyt5wc0000gn/T/ipykernel_60072/3842701405.py:4: MatplotlibDeprecationWarning: Auto-close()ing of figures upon backend switching is deprecated since 3.8 and will be removed two minor releases later.  To suppress this warning, explicitly call plt.close('all') first.
#   matplotlib.use('Qt5Agg')

# %%
# %matplotlib notebook
NUMGS = 8
csv_names = [f'f{i}_complete_grid_results.csv' for i in range(NUMGS)]

dflist = []
for i, name in enumerate(csv_names):
    try:
        df = pd.read_csv(os.path.join(path_to_csv,name))
        dflist.append(df)
    except FileNotFoundError:
        print(f'csv file {name} not found')

# %%
fig, ax = plt.subplots(1)

df1 = dflist[1]
omegavals1 = np.array(df1.columns[1:],dtype=np.float64)
rvals1 = np.array(df1.index)
r_idx1 = 1
nldos1 = (np.array(df1.iloc[r_idx1][1:]))
# plt.plot(omegavals1, nldos1)

# plt.loglog(omegavals, nldos)
# ax.loglog(omegavals1, np.abs(nldos1))

# %%
# %matplotlib notebook

df5 = dflist[5]
omegavals5 = np.array(df5.columns[1:],dtype=np.float64)
rvals5 = np.array(df5.index)
r_idx5 = 0
nldos5 = (np.array(df5.iloc[r_idx5][1:]))
# plt.plot(omegavals5, nldos5)

# plt.loglog(omegavals, nldos)

# plt.loglog(omegavals5, np.abs(nldos5))
# plt.loglog(omegavals1, np.abs(nldos1))
# plt.loglog(omegavals1, np.abs(nldos1/nldos5))

plt.plot(omegavals5, np.abs(nldos5))
plt.plot(omegavals1, np.abs(nldos1))
plt.plot(omegavals1, np.abs(nldos1/nldos5))

p5 = find_peaks(np.abs(nldos5),prominence=0.001)
print(p5)
plt.axvline([omegavals5[p5[0][0]],], ls = '--')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1483]), {'prominences': array([0.00297489]), 'left_bases': array([513]), 'right_bases': array([1784])})
