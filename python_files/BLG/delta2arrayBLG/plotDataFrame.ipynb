# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import sys, os
path_to_csv = './csvresults/'

# %%
# %matplotlib notebook
NUMGS = 8
csv_names = [f'f{i}_complete_grid_results.csv' for i in range(NUMGS)]

dflist = []
for i, name in enumerate(csv_names):
    try:
        df = pd.read_csv(os.path.join(path_to_csv,name))
        dflist.append(df)
    except FileNotFoundError:
        print(f'csv file {name} not found')
    


df = dflist[4]
omegavals = np.array(df.columns[1:],dtype=np.float64)
rvals = np.array(df.index)
r_idx = 0
nldos = (np.array(df.iloc[r_idx][1:]))
plt.plot(omegavals, nldos)

# plt.loglog(omegavals, nldos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.iloc?

# %%
df.head
# Out:
# <bound method NDFrame.head of    Unnamed: 0     1e-06  1.004985418006524e-06  1.0099956904057458e-06  \
# 0           0  0.003136               0.003235                0.002762
# 1           1  0.003168               0.003234                0.002838
# 2           2  0.003166               0.003232                0.002898
# 3           3  0.003170               0.003228                0.002967
# 4           4  0.003158               0.003223                0.002895
# 5           5  0.003149               0.003217                0.002759
# 6           6  0.003141               0.003209                0.002723
# 7           7  0.003133               0.003200                0.002759
# 8           8  0.003124               0.003189                0.002790
# 9           9  0.003117               0.003177                0.002907
#
#    1.0150309411072061e-06  1.0200912946381813e-06  1.0251768761467666e-06  \
# 0                0.003235                0.002869                0.003235
# 1                0.003234                0.002968                0.003234
# 2                0.003232                0.003017                0.003232
# 3                0.003228                0.003088                0.003228
# 4                0.003223                0.003017                0.003223
# 5                0.003217                0.002949                0.003217
# 6                0.003209                0.002900                0.003209
# 7                0.003200                0.002909                0.003200
# 8                0.003189                0.002929                0.003189
# 9                0.003177                0.003031                0.003177
#
#    1.030287811404981e-06  1.0354242268118615e-06  1.0405862493965986e-06  ...  \
# 0               0.003235                0.001075                0.001844  ...
# 1               0.003234                0.001059                0.001906  ...
# 2               0.003232                0.001069                0.001969  ...
# 3               0.003228                0.001450                0.002322  ...
# 4               0.003223                0.001074                0.001983  ...
# 5               0.003217                0.001102                0.001840  ...
# 6               0.003209                0.001097                0.001862  ...
# 7               0.003200                0.001084                0.001851  ...
# 8               0.003189                0.001096                0.001845  ...
# 9               0.003177                0.001366                0.002173  ...
#
#    2.868688627208856  2.882990239146054  2.897363150596926  \
# 0           0.267457           0.270048           0.272400
# 1           0.021295           0.019661           0.018080
# 2          -0.014248          -0.012574          -0.011080
# 3           0.021338           0.020673           0.019966
# 4           0.005133           0.005135           0.005026
# 5          -0.004950          -0.005888          -0.006906
# 6          -0.002723          -0.002034          -0.001300
# 7           0.007349           0.006881           0.006176
# 8          -0.004727          -0.005571          -0.006272
# 9          -0.002565          -0.001777          -0.001052
#
#    2.9118077170193453  2.926324295643309  2.940913245479738  \
# 0            0.274470           0.276229           0.277668
# 1            0.016568           0.015138           0.013795
# 2           -0.009811          -0.008801          -0.008064
# 3            0.019240           0.018523           0.017834
# 4            0.004757           0.004289           0.003598
# 5           -0.007966          -0.009024          -0.010033
# 6           -0.000562           0.000140           0.000772
# 7            0.005259           0.004169           0.002954
# 8           -0.006823          -0.007222          -0.007470
# 9           -0.000406           0.000155           0.000640
#
#    2.955574927329372  2.9703097037917106  2.985117939273947       3.0
# 0           0.278799            0.279646           0.280254  0.280674
# 1           0.012539            0.011360           0.010249  0.009188
# 2          -0.007596           -0.007372          -0.007355 -0.007497
# 3           0.017187            0.016591           0.016046  0.015548
# 4           0.002677            0.001540           0.000215 -0.001263
# 5          -0.010953           -0.011747          -0.012386 -0.012850
# 6           0.001312            0.001751           0.002089  0.002336
# 7           0.001667            0.000360          -0.000919 -0.002129
# 8          -0.007565           -0.007507          -0.007290 -0.006911
# 9           0.001063            0.001440           0.001783  0.002101
#
# [10 rows x 3001 columns]>
